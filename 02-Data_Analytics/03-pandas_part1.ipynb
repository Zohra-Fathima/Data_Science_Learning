# %%
import pandas as pd

# %%
info={
    "name":["rahul","zohra","fathima"],
    "CGPA":[9.5,8.7,6.0]
}

df=pd.DataFrame(info)

print(df)

# %%
df

# %%
s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))

#indexing
print(s[0])
print(s[3])

# %%
#label
s=pd.Series([25,23,26,27],index=["adam","bob","eve","muna"])
print(s)
print(s["adam"])
print(s.index)

# %%
#vectorize

s1=pd.Series([1,2,3,4,5])
s2=pd.Series([10,20,30,40,50])

print(s1+s2)

#values are mutable, size is immutable
s1[0]=100
print(s1)

changed_s1=s1.drop(0)
print(changed_s1)

print(s1)

# %%
info={
    "name":["rahul","zohra","fathima"],
    "age":[23,24,25],
    "CGPA":[9.5,8.7,6.0]
}

df=pd.DataFrame(info)
print(df,type(df))

print(df.index)#to print rows labels use .index
print(df.columns)#to print columns labels use .columns

# %%
df=pd.DataFrame([["adam",40],["bob",20],["eve",30]],columns=["name","age"])
print(df)
